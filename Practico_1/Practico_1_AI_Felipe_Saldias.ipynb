# %% [markdown]
# ## Practical HomeWork N°1 AI
#
# ### Solved by Felipe Saldias
#
# [Activity's statement](https://docs.google.com/document/d/1-oZrexNbKHGwV239iYcXHLaKSXkjtgPddWKaLA2FMu0/edit)

# %%
#import  necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


##seeting seaborn styles
sns.set()

##seeting some readability settings for pandas
pd.set_option("display.precision", 3)
pd.set_option("display.max_rows", 25)

# %%
# %ls
# Out:
# Practico_1_AI_Felipe_Saldias.ipynb  SDSS-DR14.csv

# %%
print(8)
# Out:
# 8

# %%
#importamos el dataset y
#se elimina el objid ya que tiene el mismo valor para todos, lo mas probable es que 
#corresponda a la id del observatorio o algo asi 
#df = pd.read_csv("SDSS-DR14.csv").drop(["objid",'rerun'], axis=1)
df = pd.read_csv("SDSS-DR14.csv").drop(["objid"], axis=1)
df = pd.read_csv("SDSS-DR14.csv")

#display(df[:10])
#df.groupby("rerun").describe()

display(type(df[["rerun"]]),
       type(df.loc[:,"rerun"]))

display(df.loc[:,"objid"].value_counts(),
        df.loc[:,"run"].value_counts(),
        df.loc[:,"rerun"].value_counts())
# Out:
# pandas.core.frame.DataFrame
# pandas.core.series.Series
# 1.238e+18    10000
# Name: objid, dtype: int64
# 756     3060
# 752     2086
# 1345     915
# 1350     540
# 1140     527
# 745      453
# 1035     396
# 1412     347
# 1302     246
# 1331     245
# 1231     245
# 1334     212
# 1239     197
# 1336     182
# 1404     137
# 1045     112
# 1402      49
# 308       31
# 1411      10
# 1356       4
# 727        4
# 1119       1
# 1332       1
# Name: run, dtype: int64
# 301    10000
# Name: rerun, dtype: int64

# %%
df.describe()
# Out:
#            objid         ra        dec          u          g          r  \
# count  1.000e+04  10000.000  10000.000  10000.000  10000.000  10000.000
# mean   1.238e+18    175.530     14.836     18.619     17.372     16.841
# std    0.000e+00     47.783     25.212      0.829      0.945      1.068
# min    1.238e+18      8.235     -5.383     12.989     12.800     12.432
# 25%    1.238e+18    157.371     -0.539     18.178     16.815     16.173
# 50%    1.238e+18    180.395      0.404     18.853     17.495     16.859
# 75%    1.238e+18    201.547     35.649     19.259     18.010     17.513
# max    1.238e+18    260.884     68.542     19.600     19.919     24.802
#
#                i          z        run    rerun     camcol      field  \
# count  10000.000  10000.000  10000.000  10000.0  10000.000  10000.000
# mean      16.584     16.423    981.035    301.0      3.649    302.380
# std        1.142      1.203    273.305      0.0      1.666    162.578
# min       11.947     11.610    308.000    301.0      1.000     11.000
# 25%       15.854     15.618    752.000    301.0      2.000    184.000
# 50%       16.555     16.390    756.000    301.0      4.000    299.000
# 75%       17.259     17.141   1331.000    301.0      5.000    414.000
# max       28.180     22.833   1412.000    301.0      6.000    768.000
#
#        specobjid   redshift      plate        mjd    fiberid
# count  1.000e+04  1.000e+04  10000.000  10000.000  10000.000
# mean   1.645e+18  1.437e-01   1460.986  52943.533    353.069
# std    2.014e+18  3.888e-01   1788.778   1511.151    206.298
# min    2.996e+17 -4.136e-03    266.000  51578.000      1.000
# 25%    3.389e+17  8.090e-05    301.000  51900.000    186.750
# 50%    4.967e+17  4.259e-02    441.000  51997.000    351.000
# 75%    2.881e+18  9.258e-02   2559.000  54468.000    510.000
# max    9.469e+18  5.354e+00   8410.000  57481.000   1000.000

# %%
#value_counts() is only aplicable in pd.Series to show wich are the differents values you can
#get in a series and how many times is each

display("cantidad de valores diferentes: ", df.loc[:,"run"].value_counts(),
        df.loc[:,"rerun"].value_counts())
# Out:
# 'cantidad de valores diferentes: '
# 756     3060
# 752     2086
# 1345     915
# 1350     540
# 1140     527
# 745      453
# 1035     396
# 1412     347
# 1302     246
# 1331     245
# 1231     245
# 1334     212
# 1239     197
# 1336     182
# 1404     137
# 1045     112
# 1402      49
# 308       31
# 1411      10
# 1356       4
# 727        4
# 1119       1
# 1332       1
# Name: run, dtype: int64
# 301    10000
# Name: rerun, dtype: int64

# %%
#vemos los estadisticos de la informacion agrupada por clase
#df.dtypes
agrupados=df.groupby(['class']).describe()
agrupados
# Out:
#          objid                                                       \
#          count       mean      std        min        25%        50%
# class
# GALAXY  4998.0  1.238e+18    0.000  1.238e+18  1.238e+18  1.238e+18
# QSO      850.0  1.238e+18    0.000  1.238e+18  1.238e+18  1.238e+18
# STAR    4152.0  1.238e+18  256.031  1.238e+18  1.238e+18  1.238e+18
#
#                                   ra           ...      mjd          fiberid  \
#               75%        max   count     mean  ...      75%      max   count
# class                                          ...
# GALAXY  1.238e+18  1.238e+18  4998.0  177.334  ...  51999.0  56799.0  4998.0
# QSO     1.238e+18  1.238e+18   850.0  177.468  ...  52366.5  57391.0   850.0
# STAR    1.238e+18  1.238e+18  4152.0  172.962  ...  54891.0  57481.0  4152.0
#
#
#            mean      std  min     25%    50%     75%     max
# class
# GALAXY  340.109  186.853  1.0  186.25  345.0  496.00   994.0
# QSO     381.559  211.083  5.0  215.00  386.5  532.00   980.0
# STAR    362.838  225.633  1.0  179.00  351.0  526.25  1000.0
#
# [3 rows x 136 columns]

# %%
df[['ra','u']]
# Out:
#            ra       u
# 0     183.531  19.474
# 1     183.598  18.663
# 2     183.680  19.383
# 3     183.871  17.765
# 4     183.883  17.550
# ...       ...     ...
# 9995  131.316  18.818
# 9996  131.306  18.273
# 9997  131.553  18.758
# 9998  131.477  18.883
# 9999  131.665  19.276
#
# [10000 rows x 2 columns]

# %%
#df.index
df.columns
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %%
agrupados.columns
# Out:
# MultiIndex([(  'objid', 'count'),
#             (  'objid',  'mean'),
#             (  'objid',   'std'),
#             (  'objid',   'min'),
#             (  'objid',   '25%'),
#             (  'objid',   '50%'),
#             (  'objid',   '75%'),
#             (  'objid',   'max'),
#             (     'ra', 'count'),
#             (     'ra',  'mean'),
#             ...
#             (    'mjd',   '75%'),
#             (    'mjd',   'max'),
#             ('fiberid', 'count'),
#             ('fiberid',  'mean'),
#             ('fiberid',   'std'),
#             ('fiberid',   'min'),
#             ('fiberid',   '25%'),
#             ('fiberid',   '50%'),
#             ('fiberid',   '75%'),
#             ('fiberid',   'max')],
#            length=136)

# %%
#agrupados.columns
#MultiIndex([(     'ra', 'count'), ...., ('fiberid',   'max')],length=128)
#agrupados.index
#Index(['GALAXY', 'QSO', 'STAR'], dtype='object', name='class')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-d317702c87d9> in <module>
# ----> 1 agrupados.columns
#       2 #MultiIndex([(     'ra', 'count'), ...., ('fiberid',   'max')],length=128)
#       3 #agrupados.index
#       4 #Index(['GALAXY', 'QSO', 'STAR'], dtype='object', name='class')
#
# ~/.conda/envs/ai/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     577             return self[attr]
#     578
# --> 579         raise AttributeError(
#     580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'columns'

# %%
agrupados[('ra','mean')]#['GALAXY']
# Out:
# class
# GALAXY    177.334
# QSO       177.468
# STAR      172.962
# Name: (ra, mean), dtype: float64

# %%
s = pd.Series([3.124, 5.124, 2.1416, 10.])
s[0]
# Out:
# 3.124

# %%
df[2:2,'mean']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-4ff2f458d7ff> in <module>
# ----> 1 df[2:2,'mean']
#
# ~/.conda/envs/ai/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/.conda/envs/ai/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2644                 )
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#    2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(2, 2, None), 'mean')' is an invalid key

# %%
agrupados[a]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-06c238564dd6> in <module>
# ----> 1 agrupados['mean',]
#
# ~/.conda/envs/ai/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2797         if is_single_key:
#    2798             if self.columns.nlevels > 1:
# -> 2799                 return self._getitem_multilevel(key)
#    2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#
# ~/.conda/envs/ai/lib/python3.8/site-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    2847     def _getitem_multilevel(self, key):
#    2848         # self.columns is a MultiIndex
# -> 2849         loc = self.columns.get_loc(key)
#    2850         if isinstance(loc, (slice, Series, np.ndarray, Index)):
#    2851             new_columns = self.columns[loc]
#
# ~/.conda/envs/ai/lib/python3.8/site-packages/pandas/core/indexes/multi.py in get_loc(self, key, method)
#    2683
#    2684         if start == stop:
# -> 2685             raise KeyError(key)
#    2686
#    2687         if not follow_key:
#
# KeyError: ('mean',)

# %% [markdown]
# #de aqui se infiere que claramente la clase QSO que cuenta con menos ejemplos que las otras
# ```python
# print "Hello World"
# ```

# %%
#df.drop(['class'], axis=1)
##Estudio de la data 
print("Valores NaN en el data set?:  ", df.isnull().values.any())
print("largo de la data :", +len(df))
df.describe()
# Out:
# Valores NaN en el data set?:   False
# largo de la data : 10000
#               ra        dec          u          g          r          i          z        run    rerun     camcol      field  specobjid   redshift      plate        mjd    fiberid
# count  10000.000  10000.000  10000.000  10000.000  10000.000  10000.000  10000.000  10000.000  10000.0  10000.000  10000.000  1.000e+04  1.000e+04  10000.000  10000.000  10000.000
# mean     175.530     14.836     18.619     17.372     16.841     16.584     16.423    981.035    301.0      3.649    302.380  1.645e+18  1.437e-01   1460.986  52943.533    353.069
# std       47.783     25.212      0.829      0.945      1.068      1.142      1.203    273.305      0.0      1.666    162.578  2.014e+18  3.888e-01   1788.778   1511.151    206.298
# min        8.235     -5.383     12.989     12.800     12.432     11.947     11.610    308.000    301.0      1.000     11.000  2.996e+17 -4.136e-03    266.000  51578.000      1.000
# 25%      157.371     -0.539     18.178     16.815     16.173     15.854     15.618    752.000    301.0      2.000    184.000  3.389e+17  8.090e-05    301.000  51900.000    186.750
# 50%      180.395      0.404     18.853     17.495     16.859     16.555     16.390    756.000    301.0      4.000    299.000  4.967e+17  4.259e-02    441.000  51997.000    351.000
# 75%      201.547     35.649     19.259     18.010     17.513     17.259     17.141   1331.000    301.0      5.000    414.000  2.881e+18  9.258e-02   2559.000  54468.000    510.000
# max      260.884     68.542     19.600     19.919     24.802     28.180     22.833   1412.000    301.0      6.000    768.000  9.469e+18  5.354e+00   8410.000  57481.000   1000.000

# %%
#Histograma para ver la distribucion de las variables 
df.hist()

#histograma por clases 
df.groupby(['class']).hist()
print("as")
# Out:
# as

# %%
sns.pairplot(df)

# %%
Y_labels=df['class']
X_features

# %%
df
# Out:
#            ra     dec       u       g       r       i       z   run  rerun  camcol  field  specobjid   class   redshift  plate    mjd  fiberid
# 0     183.531   0.090  19.474  17.042  15.947  15.503  15.225   752    301       4    267  3.722e+18    STAR -8.960e-06   3306  54922      491
# 1     183.598   0.135  18.663  17.214  16.676  16.489  16.392   752    301       4    267  3.638e+17    STAR -5.490e-05    323  51615      541
# 2     183.680   0.126  19.383  18.192  17.474  17.087  16.801   752    301       4    268  3.233e+17  GALAXY  1.231e-01    287  52023      513
# 3     183.871   0.050  17.765  16.603  16.161  15.982  15.904   752    301       4    269  3.722e+18    STAR -1.106e-04   3306  54922      510
# 4     183.883   0.103  17.550  16.263  16.439  16.555  16.613   752    301       4    269  3.722e+18    STAR  5.904e-04   3306  54922      512
# ...       ...     ...     ...     ...     ...     ...     ...   ...    ...     ...    ...        ...     ...        ...    ...    ...      ...
# 9995  131.316  51.540  18.818  17.471  16.915  16.683  16.506  1345    301       3    161  5.033e+17  GALAXY  2.758e-02    447  51877      246
# 9996  131.306  51.671  18.273  17.438  17.077  16.717  16.699  1345    301       3    162  5.033e+17  GALAXY  1.178e-01    447  51877      228
# 9997  131.553  51.667  18.758  17.778  17.519  17.433  17.420  1345    301       3    162  8.223e+18    STAR -4.016e-04   7303  57013      622
# 9998  131.477  51.753  18.883  17.911  17.532  17.363  17.140  1345    301       3    163  5.033e+17  GALAXY  1.402e-02    447  51877      229
# 9999  131.665  51.805  19.276  17.378  16.305  15.835  15.506  1345    301       3    163  5.033e+17  GALAXY  1.184e-01    447  51877      233
#
# [10000 rows x 17 columns]
